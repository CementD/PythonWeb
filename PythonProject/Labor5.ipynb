# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# # Task1

# %% [markdown]
# # Task1

# %%
df = pd.read_csv("transactions.csv")
df.head()
# Out:
#    order_id  user_id  amount        date
# 0         1      101  120.50  2024-01-01
# 1         2      102   89.99  2024-01-02
# 2         3      103   45.00  2024-01-02
# 3         4      104  230.10  2024-01-03
# 4         5      105   15.75  2024-01-03

# %%
df
# Out:
#     order_id  user_id  amount        date
# 0          1      101  120.50  2024-01-01
# 1          2      102   89.99  2024-01-02
# 2          3      103   45.00  2024-01-02
# 3          4      104  230.10  2024-01-03
# 4          5      105   15.75  2024-01-03
# 5          6      106  500.00  2024-01-04
# 6          7      107     NaN  2024-01-04
# 7          8      108   75.20  2024-01-05
# 8          9      109   60.00  2024-01-05
# 9         10      110  300.45  2024-01-06
# 10        11      111   22.30  2024-01-06
# 11        12      112   18.99  2024-01-07
# 12        13      113  150.00  2024-01-07
# 13        14      114  999.99  2024-01-08
# 14        15      115    5.99  2024-01-08
# 15        16      116   42.42  2024-01-09
# 16        17      117     NaN  2024-01-09
# 17        18      118  210.00  2024-01-10
# 18        19      119  130.00  2024-01-10
# 19        20      120   80.80  2024-01-11
# 20        21      121   55.55  2024-01-11
# 21        22      122  600.00  2024-01-12
# 22        23      123   75.00  2024-01-12
# 23        24      124   95.95  2024-01-13
# 24        25      125  110.10  2024-01-13

# %%
print(f"Nan count: \n{df.isna().sum()}")
# Out:
# Nan count:
# order_id    0
# user_id     0
# amount      2
# date        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order_id  25 non-null     int64
#  1   user_id   25 non-null     int64
#  2   amount    23 non-null     float64
#  3   date      25 non-null     str
# dtypes: float64(1), int64(2), str(1)
# memory usage: 932.0 bytes

# %%
df.describe()
# Out:
#         order_id     user_id      amount
# count  25.000000   25.000000   23.000000
# mean   13.000000  113.000000  175.394783
# std     7.359801    7.359801  233.797434
# min     1.000000  101.000000    5.990000
# 25%     7.000000  107.000000   50.275000
# 50%    13.000000  113.000000   89.990000
# 75%    19.000000  119.000000  180.000000
# max    25.000000  125.000000  999.990000

# %%
nan_arr = np.array(df["amount"])
not_nan_mask = ~np.isnan(arr) 
arr = arr[not_nan_mask]

print(f"Count: {len(arr)}")
print(f"Average: {arr.mean()}")
print(f"{np.median(arr)}")
print(f"{arr.min()}")
print(f"{arr.max()}")
print(f"{np.percentile(arr, 25)}")
print(f"{np.percentile(arr, 50)}")
print(f"{np.percentile(arr, 75)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 nan_arr = np.array(df["amount"])
# ----> 2 not_nan_mask = ~np.isnan(arr)
#       3 arr = arr[not_nan_mask]
#       5 print(f"Count: {len(arr)}")
#
# NameError: name 'arr' is not defined

# %%
plt.hist(arr)
plt.title("Amounts")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.hist(arr)
#       2 plt.title("Amounts")
#       3 plt.show()
#
# NameError: name 'arr' is not defined

# %%
plt.boxplot(arr)
plt.title = "Amounts"
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.boxplot(arr)
#       2 plt.title = "Amounts"
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # Task2

# %%
arr2_1 = np.array([12, 500, 15, 22, 999, 18, 10])
arr2 = arr2_1.reshape((7, 1))
print(arr2)
# Out:
# [[ 12]
#  [500]
#  [ 15]
#  [ 22]
#  [999]
#  [ 18]
#  [ 10]]

# %%
print(f"Average: {arr2.mean()}")
print(f"Median: {np.median(arr2)}")
print(f"Std: {arr2.std():.2f}")
print(f"IQR: {np.percentile(arr2, 75) - np.percentile(arr2, 25)}")
print(f"MAD: {stats.median_abs_deviation(arr2)}")
print(f"Skew: {stats.skew(arr2)} \nKurtosis: {stats.kurtosis(arr2)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(f"Average: {arr2.mean()}")
#       2 print(f"Median: {np.median(arr2)}")
#       3 print(f"Std: {arr2.std():.2f}")
#
# NameError: name 'arr2' is not defined

# %%
plt.hist(arr2)
plt.title("Nums")
plt.xlabel("Value")
plt.ylabel("Count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.hist(arr2)
#       2 plt.title("Nums")
#       3 plt.xlabel("Value")
#
# NameError: name 'plt' is not defined

# %%
|
# Out:
#   Cell In[9], line 1
#     |
#     ^
# SyntaxError: invalid syntax

# %%
|
# Out:
#   Cell In[10], line 1
#     |
#     ^
# SyntaxError: invalid syntax

# %%
|
# Out:
#   Cell In[11], line 1
#     |
#     ^
# SyntaxError: invalid syntax
