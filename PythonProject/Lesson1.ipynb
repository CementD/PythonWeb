# %%
x = 5
x
# Out:
# 5

# %%
x
# Out:
# 5

# %% [markdown]
# # Test1
# ## Test2
# ### Test3
#
# **bold** bold
# *cursive*
# - el 1
# - el2 2

# %% [markdown]
# | A | B |
# |---|---|
# | C | D |

# %% [markdown]
# <h1>Tetx1</h1>

# %%
# !pip install rich
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    ------------- -------------------------- 1/3 [markdown-it-py]
#    -------------------------- ------------- 2/3 [rich]
#    -------------------------- ------------- 2/3 [rich]
#    -------------------------- ------------- 2/3 [rich]
#    -------------------------- ------------- 2/3 [rich]
#    ---------------------------------------- 3/3 [rich]
#
# ...
#   WARNING: The script markdown-it.exe is installed in 'C:\Users\User\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !pip3 install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np
import rich as rc

# %%
np
# Out:
# <module 'numpy' from 'C:\\Users\\User\\AppData\\Roaming\\Python\\Python313\\site-packages\\numpy\\__init__.py'>

# %%
rc
# Out:
# <module 'rich' from 'C:\\Users\\User\\AppData\\Roaming\\Python\\Python313\\site-packages\\rich\\__init__.py'>

# %%
"Hello, Jupiter"
# Out:
# 'Hello, Jupiter'

# %%
str = "Hello, Jupiter"
print(str)
# Out:
# Hello, Jupiter

# %%
a = 15
b = 7

# %% [markdown]
# ## Result of calc of sum and sub

# %%
print("Multi: ", a * b)
print("Division: ", a / b)
# Out:
# Multi:  105
# Division:  2.142857142857143

# %%
res = a - b
res
# Out:
# 8

# %%
a + b
# Out:
# 22

# %%
a = int(input("Enter age: "))
print(f'Age: {a}')
# Out:
# Enter age:  7
# Age: 7
